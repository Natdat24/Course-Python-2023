# %% [markdown]
# # Домашнє завдання до лекції 4: Pandas

# %% [markdown]
# У цьому домашньому завданні ми працюємо з набором даних про продажі в різних магазинах мережі супермаркетів. Дані взяті з Kaggle, за [посиланням](https://www.kaggle.com/aungpyaeap/supermarket-sales) Ви можете знайти їх опис. Прочитати опис даних - хороша практика перед початком роботи, тож дуже раджу це зробити :)
# Дані були завантажені для Вас в папку `data/` на гугл диску, аби бути на 100% впевненими, що ви працюєте з тими даними, з якими працювала я, коли готувала завдання. Завантажте дані собі локально. Накраще це зробити в окрему директорію `/data` на вашому компʼютері. Дані ми не заливаємо зазвичай в git. Але для демонстрації своєї роботи їх  можна завантажити собі на гугл диск, дати доступ за посиланням і додати в гіт посилання на дані.
#
# У цьому домашньому завданні особливо важливо **уважно** читати формулювання завдання і всі коментарі.
# В цьому домашньому завданні також треба по максимуму використовувати функціонал бібліотеки pandas, навіть якщо існують альтернативні способи зробити те самеь.

# %% [markdown]
# 1.За допомогою бібліотеки Pandas, викликом однієї функції зчитайте набір даних із файлу 'supermarket_sales.csv'.

# %%
! conda install pandas numpy
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
import numpy as np
import pandas as pd

# %%
# ?pd.read_csv

# %%
df = pd.read_csv('../Downloads/Data/supermarket_sales.csv', index_col='Invoice ID')

# %%
df_shape = df.shape

# %%
df_shape[0]
# Out:
# 1000

# %%
df_shape[1]
# Out:
# 16

# %%
df_shape
# Out:
# (1000, 16)

# %% [markdown]
# 2.За допомогою бібліотеки Pandas виведіть перші 5 і останні 5 записів у наборі даних.

# %%
df.head(1000)
# Out:
#             Branch       City Customer type  Gender            Product line  \
# Invoice ID
# 750-67-8428      A     Yangon        Member  Female       Health and beauty
# 226-31-3081      C  Naypyitaw        Normal  Female  Electronic accessories
# 631-41-3108      A     Yangon        Normal    Male      Home and lifestyle
# 123-19-1176      A     Yangon        Member    Male       Health and beauty
# 373-73-7910      A     Yangon        Normal    Male       Sports and travel
# ...            ...        ...           ...     ...                     ...
# 233-67-5758      C  Naypyitaw        Normal    Male       Health and beauty
# 303-96-2227      B   Mandalay        Normal  Female      Home and lifestyle
# 727-02-1313      A     Yangon        Member    Male      Food and beverages
# 347-56-2442      A     Yangon        Normal    Male      Home and lifestyle
# 849-09-3807      A     Yangon        Member  Female     Fashion accessories
#
#              Unit price  Quantity   Tax 5%      Total       Date   Time  \
# Invoice ID
# 750-67-8428       74.69         7  26.1415   548.9715   1/5/2019  13:08
# 226-31-3081       15.28         5   3.8200    80.2200   3/8/2019  10:29
# 631-41-3108       46.33         7  16.2155   340.5255   3/3/2019  13:23
# 123-19-1176       58.22         8  23.2880   489.0480  1/27/2019  20:33
# 373-73-7910       86.31         7  30.2085   634.3785   2/8/2019  10:37
# ...                 ...       ...      ...        ...        ...    ...
# 233-67-5758       40.35         1   2.0175    42.3675  1/29/2019  13:46
# 303-96-2227       97.38        10  48.6900  1022.4900   3/2/2019  17:16
# 727-02-1313       31.84         1   1.5920    33.4320   2/9/2019  13:22
# 347-56-2442       65.82         1   3.2910    69.1110  2/22/2019  15:33
# 849-09-3807       88.34         7  30.9190   649.2990  2/18/2019  13:28
#
#                  Payment    cogs  gross margin percentage  gross income  \
# Invoice ID
# 750-67-8428      Ewallet  522.83                 4.761905       26.1415
# 226-31-3081         Cash   76.40                 4.761905        3.8200
# 631-41-3108  Credit card  324.31                 4.761905       16.2155
# 123-19-1176      Ewallet  465.76                 4.761905       23.2880
# 373-73-7910      Ewallet  604.17                 4.761905       30.2085
# ...                  ...     ...                      ...           ...
# 233-67-5758      Ewallet   40.35                 4.761905        2.0175
# 303-96-2227      Ewallet  973.80                 4.761905       48.6900
# 727-02-1313         Cash   31.84                 4.761905        1.5920
# 347-56-2442         Cash   65.82                 4.761905        3.2910
# 849-09-3807         Cash  618.38                 4.761905       30.9190
#
#              Rating
# Invoice ID
# 750-67-8428     9.1
# 226-31-3081     9.6
# 631-41-3108     7.4
# 123-19-1176     8.4
# 373-73-7910     5.3
# ...             ...
# 233-67-5758     6.2
# 303-96-2227     4.4
# 727-02-1313     7.7
# 347-56-2442     4.1
# 849-09-3807     6.6
#
# [1000 rows x 16 columns]

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![Screenshot%20%285%29.png](attachment:Screenshot%20%285%29.png)

# %%
df
# Out:
#             Branch       City Customer type  Gender            Product line  \
# Invoice ID
# 750-67-8428      A     Yangon        Member  Female       Health and beauty
# 226-31-3081      C  Naypyitaw        Normal  Female  Electronic accessories
# 631-41-3108      A     Yangon        Normal    Male      Home and lifestyle
# 123-19-1176      A     Yangon        Member    Male       Health and beauty
# 373-73-7910      A     Yangon        Normal    Male       Sports and travel
# ...            ...        ...           ...     ...                     ...
# 233-67-5758      C  Naypyitaw        Normal    Male       Health and beauty
# 303-96-2227      B   Mandalay        Normal  Female      Home and lifestyle
# 727-02-1313      A     Yangon        Member    Male      Food and beverages
# 347-56-2442      A     Yangon        Normal    Male      Home and lifestyle
# 849-09-3807      A     Yangon        Member  Female     Fashion accessories
#
#              Unit price  Quantity   Tax 5%      Total       Date   Time  \
# Invoice ID
# 750-67-8428       74.69         7  26.1415   548.9715   1/5/2019  13:08
# 226-31-3081       15.28         5   3.8200    80.2200   3/8/2019  10:29
# 631-41-3108       46.33         7  16.2155   340.5255   3/3/2019  13:23
# 123-19-1176       58.22         8  23.2880   489.0480  1/27/2019  20:33
# 373-73-7910       86.31         7  30.2085   634.3785   2/8/2019  10:37
# ...                 ...       ...      ...        ...        ...    ...
# 233-67-5758       40.35         1   2.0175    42.3675  1/29/2019  13:46
# 303-96-2227       97.38        10  48.6900  1022.4900   3/2/2019  17:16
# 727-02-1313       31.84         1   1.5920    33.4320   2/9/2019  13:22
# 347-56-2442       65.82         1   3.2910    69.1110  2/22/2019  15:33
# 849-09-3807       88.34         7  30.9190   649.2990  2/18/2019  13:28
#
#                  Payment    cogs  gross margin percentage  gross income  \
# Invoice ID
# 750-67-8428      Ewallet  522.83                 4.761905       26.1415
# 226-31-3081         Cash   76.40                 4.761905        3.8200
# 631-41-3108  Credit card  324.31                 4.761905       16.2155
# 123-19-1176      Ewallet  465.76                 4.761905       23.2880
# 373-73-7910      Ewallet  604.17                 4.761905       30.2085
# ...                  ...     ...                      ...           ...
# 233-67-5758      Ewallet   40.35                 4.761905        2.0175
# 303-96-2227      Ewallet  973.80                 4.761905       48.6900
# 727-02-1313         Cash   31.84                 4.761905        1.5920
# 347-56-2442         Cash   65.82                 4.761905        3.2910
# 849-09-3807         Cash  618.38                 4.761905       30.9190
#
#              Rating
# Invoice ID
# 750-67-8428     9.1
# 226-31-3081     9.6
# 631-41-3108     7.4
# 123-19-1176     8.4
# 373-73-7910     5.3
# ...             ...
# 233-67-5758     6.2
# 303-96-2227     4.4
# 727-02-1313     7.7
# 347-56-2442     4.1
# 849-09-3807     6.6
#
# [1000 rows x 16 columns]

# %% [markdown]
# 3.Виведіть кількість рядків і кількість колонок в наборі даних. Відповідь сформуйте використовуючи fstring.

# %%
df_shape
# Out:
# (1000, 16)

# %%
df_shape[0:3]
# Out:
# (1000, 16)

# %%
df_shape
print (f'Набір даних містить {df_shape [0]} рядків та {df_shape [1]} колонок.')
# Out:
# Набір даних містить 1000 рядків та 16 колонок.

# %%
len(df.columns)
# Out:
# 16

# %%
## чомусь в мене 16 стовпчиків, як добавити колонку з номерацією рядків

# %% [markdown]
# Очікувана відповідь:
#     ```Набір даних містить 1000 рядків та 17 колонок.```

# %% [markdown]
# 4.Виведіть назви колонок у наборі даних разом з їхніми типами.

# %%
df.dtypes
# Out:
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![Screenshot%20%286%29.png](attachment:Screenshot%20%286%29.png)

# %% [markdown]
# 5.Скільки в даному наборі даних є колонок якого типу (текстового, int, float)?

# %%
df.dtypes.value_counts()
# Out:
# object     8
# float64    7
# int64      1
# dtype: int64

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![Screenshot%20%287%29.png](attachment:Screenshot%20%287%29.png)

# %% [markdown]
# 6.Скільки всього покупок зробили покупці з різним типом клієнта (`Customer type`)? Тут можна отримати відповідь одним рядком коду і це варіант реалізації, якому варто надати перевагу.

# %%
df = df.rename(columns={'Customer type': 'Customer_type'})

# %%
df
# Out:
#             Branch       City Customer_type  Gender            Product line  \
# Invoice ID
# 750-67-8428      A     Yangon        Member  Female       Health and beauty
# 226-31-3081      C  Naypyitaw        Normal  Female  Electronic accessories
# 631-41-3108      A     Yangon        Normal    Male      Home and lifestyle
# 123-19-1176      A     Yangon        Member    Male       Health and beauty
# 373-73-7910      A     Yangon        Normal    Male       Sports and travel
# ...            ...        ...           ...     ...                     ...
# 233-67-5758      C  Naypyitaw        Normal    Male       Health and beauty
# 303-96-2227      B   Mandalay        Normal  Female      Home and lifestyle
# 727-02-1313      A     Yangon        Member    Male      Food and beverages
# 347-56-2442      A     Yangon        Normal    Male      Home and lifestyle
# 849-09-3807      A     Yangon        Member  Female     Fashion accessories
#
#              Unit price  Quantity   Tax 5%      Total       Date   Time  \
# Invoice ID
# 750-67-8428       74.69         7  26.1415   548.9715   1/5/2019  13:08
# 226-31-3081       15.28         5   3.8200    80.2200   3/8/2019  10:29
# 631-41-3108       46.33         7  16.2155   340.5255   3/3/2019  13:23
# 123-19-1176       58.22         8  23.2880   489.0480  1/27/2019  20:33
# 373-73-7910       86.31         7  30.2085   634.3785   2/8/2019  10:37
# ...                 ...       ...      ...        ...        ...    ...
# 233-67-5758       40.35         1   2.0175    42.3675  1/29/2019  13:46
# 303-96-2227       97.38        10  48.6900  1022.4900   3/2/2019  17:16
# 727-02-1313       31.84         1   1.5920    33.4320   2/9/2019  13:22
# 347-56-2442       65.82         1   3.2910    69.1110  2/22/2019  15:33
# 849-09-3807       88.34         7  30.9190   649.2990  2/18/2019  13:28
#
#                  Payment    cogs  gross margin percentage  gross income  \
# Invoice ID
# 750-67-8428      Ewallet  522.83                 4.761905       26.1415
# 226-31-3081         Cash   76.40                 4.761905        3.8200
# 631-41-3108  Credit card  324.31                 4.761905       16.2155
# 123-19-1176      Ewallet  465.76                 4.761905       23.2880
# 373-73-7910      Ewallet  604.17                 4.761905       30.2085
# ...                  ...     ...                      ...           ...
# 233-67-5758      Ewallet   40.35                 4.761905        2.0175
# 303-96-2227      Ewallet  973.80                 4.761905       48.6900
# 727-02-1313         Cash   31.84                 4.761905        1.5920
# 347-56-2442         Cash   65.82                 4.761905        3.2910
# 849-09-3807         Cash  618.38                 4.761905       30.9190
#
#              Rating
# Invoice ID
# 750-67-8428     9.1
# 226-31-3081     9.6
# 631-41-3108     7.4
# 123-19-1176     8.4
# 373-73-7910     5.3
# ...             ...
# 233-67-5758     6.2
# 303-96-2227     4.4
# 727-02-1313     7.7
# 347-56-2442     4.1
# 849-09-3807     6.6
#
# [1000 rows x 16 columns]

# %%
df.Customer_type.value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer_type, dtype: int64

# %% [markdown]
# Очікуваний результат може бути одного з наступних виглядів:

# %% [markdown]
# ![Screenshot%20%288%29.png](attachment:Screenshot%20%288%29.png)

# %% [markdown]
# 7.Які є продуктові лінії (колонка 'Product line') в наборі даних? Вивести унікальні назви. Результат може бути в форматі np.array, list, pd.Series - це не грає великої ролі тут. Але знову ж таки пріоритет на отриманні результату одним методом :)

# %%
df.Product_line.unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %% [markdown]
# Очікуваний результат (формат даних може бути інший, але категорії мають бути такі самі):

# %% [markdown]
# ![Screenshot%20%289%29.png](attachment:Screenshot%20%289%29.png)

# %% [markdown]
# 8.Яка середня ціна товару в кожній продуктовій лінії?
# Ціна товару міститься в колонці `'Unit price'`

# %%
df = df.rename(columns={'Product line': 'Product_line','Unit price': 'Unit_price'})

# %%
df.groupby('Product_line').Unit_price.mean().describe()
# Out:
# count     6.000000
# mean     55.646459
# std       1.366830
# min      53.551588
# 25%      54.970090
# 50%      55.662894
# 75%      56.747152
# max      57.153652
# Name: Unit_price, dtype: float64

# %%
df.groupby('Product_line').Unit_price.mean()
# Out:
# Product_line
# Electronic accessories    53.551588
# Fashion accessories       57.153652
# Food and beverages        56.008851
# Health and beauty         54.854474
# Home and lifestyle        55.316937
# Sports and travel         56.993253
# Name: Unit_price, dtype: float64

# %% [markdown]
# Очікуваний результат (бажано в такому ж форматі - тип pd.Series):

# %% [markdown]
# ![Screenshot%20%2810%29.png](attachment:Screenshot%20%2810%29.png)

# %% [markdown]
# 9.З якої покупки (рядок в цих даних) магазин отримав найбільший прибуток (`gross income`)? Виведіть рядок даних з найбільшим прибутком магазину.

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 10.А який філіал магазину ('Branch') є найприбутковішим? Який сумарний прибуток він має та в якому місті знайходиться? Може в тому місці нам розмітисти ще один магазин.
# Порахуйте результат з допомогою функціоналу Pandas та виведіть використовуючи fstring форматування.

# %% [markdown]
# Очікуваний результат: `Філіал "C" є найприбутковішим. Цей філіал знаходиться в місті Naypyitaw.`

# %% [markdown]
# 11.Перевірте програмно, чи відрізняється маржа ('gross margin percentage') для різних покупок в магазині? Дайте на основі отриманого результату відповідь: "На всі покупки однакові маржа" або "Маржа відрізняється для різних покупок".

# %% [markdown]
# 12.В якому філіалі магазину ('Branch') купують найбільше електронних аксесуарів ('Electronic accessories')? Для відповіді сформуйте таблицю в якої рядки - це назви філіалів, колонки - це назви продуктової лінійки, а значення - це кількість покупок. Дайте відповідь базуючись на сформованій таблиці. Можна просто візуально.

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![Screenshot%20%2811%29.png](attachment:Screenshot%20%2811%29.png)

# %% [markdown]
# 13.Виведіть кількість покупок погодинно та зробіть висновок, коли в магазині роблять найбільше покупок.
# Для цього створіть нову колонку в наборі даних з назвою Hour. Тип колонки - int. Виведіть тип колонки та перші 5 записів. Далі використовуючи цю колонку, сформуйте структуру, де кожній годині відповідає кількість покупок. З огляду на цю структуру дайте відповідь, о якій годині найбільше було покупок. Дивлячись на найбільш популярні для покупок години, які гіпотези про поведінку користувачів можемо зробити? Чому вони найчастіше купують саме в цей час?

# %% [markdown]
# Очікуваний результат наступний і після цього має бути ваша відповідь на питання в цьому завданні. Просто текстом.

# %% [markdown]
# ![Screenshot%20%2812%29.png](attachment:Screenshot%20%2812%29.png)

# %% [markdown]
# 14. Творче завдання :) Сформулюйте ТРИ питання до наявних даних, які допомогли б вам зрозуміти які користувачі що, де та коли найбільше/найменше купують. Звісно питання мають бути не тими, на які ми вже відповіли вище.
#     Дайте відповіді на свої питання з допомогою функціоналу pandas. Опціонально - написати, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#     Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат.

# %%
with pd.option_context("display.precision", 2):
    display(df.describe())
# Out:
#        Unit_price  Quantity   Tax 5%    Total     cogs  \
# count     1000.00   1000.00  1000.00  1000.00  1000.00
# mean        55.67      5.51    15.38   322.97   307.59
# std         26.49      2.92    11.71   245.89   234.18
# min         10.08      1.00     0.51    10.68    10.17
# 25%         32.88      3.00     5.92   124.42   118.50
# 50%         55.23      5.00    12.09   253.85   241.76
# 75%         77.94      8.00    22.45   471.35   448.91
# max         99.96     10.00    49.65  1042.65   993.00
#
#        gross margin percentage  gross income   Rating
# count                 1.00e+03       1000.00  1000.00
# mean                  4.76e+00         15.38     6.97
# std                   6.13e-14         11.71     1.72
# min                   4.76e+00          0.51     4.00
# 25%                   4.76e+00          5.92     5.50
# 50%                   4.76e+00         12.09     7.00
# 75%                   4.76e+00         22.45     8.50
# max                   4.76e+00         49.65    10.00

# %%
df.sort_values(by="Gender")
# Out:
#             Branch       City Customer_type  Gender            Product_line  \
# Invoice ID
# 750-67-8428      A     Yangon        Member  Female       Health and beauty
# 539-21-7227      B   Mandalay        Normal  Female       Sports and travel
# 213-32-1216      A     Yangon        Normal  Female  Electronic accessories
# 582-52-8065      B   Mandalay        Normal  Female     Fashion accessories
# 210-57-1719      B   Mandalay        Normal  Female       Health and beauty
# ...            ...        ...           ...     ...                     ...
# 273-84-2164      C  Naypyitaw        Member    Male  Electronic accessories
# 732-04-5373      B   Mandalay        Member    Male      Home and lifestyle
# 794-32-2436      B   Mandalay        Member    Male  Electronic accessories
# 733-33-4967      C  Naypyitaw        Normal    Male  Electronic accessories
# 642-61-4706      B   Mandalay        Member    Male      Food and beverages
#
#              Unit_price  Quantity   Tax 5%     Total       Date   Time  \
# Invoice ID
# 750-67-8428       74.69         7  26.1415  548.9715   1/5/2019  13:08
# 539-21-7227       51.54         5  12.8850  270.5850  1/26/2019  17:45
# 213-32-1216       66.06         6  19.8180  416.1780  1/23/2019  10:28
# 582-52-8065       54.31         9  24.4395  513.2295  2/22/2019  10:49
# 210-57-1719       58.24         9  26.2080  550.3680   2/5/2019  12:34
# ...                 ...       ...      ...       ...        ...    ...
# 273-84-2164       12.05         5   3.0125   63.2625  2/16/2019  15:53
# 732-04-5373       46.47         4   9.2940  195.1740   2/8/2019  10:53
# 794-32-2436       55.67         2   5.5670  116.9070  3/27/2019  15:08
# 733-33-4967       20.85         8   8.3400  175.1400   3/3/2019  19:17
# 642-61-4706       93.40         2   9.3400  196.1400  3/30/2019  16:34
#
#              Payment    cogs  gross margin percentage  gross income  Rating
# Invoice ID
# 750-67-8428  Ewallet  522.83                 4.761905       26.1415     9.1
# 539-21-7227     Cash  257.70                 4.761905       12.8850     4.2
# 213-32-1216     Cash  396.36                 4.761905       19.8180     7.3
# 582-52-8065     Cash  488.79                 4.761905       24.4395     8.9
# 210-57-1719     Cash  524.16                 4.761905       26.2080     9.7
# ...              ...     ...                      ...           ...     ...
# 273-84-2164  Ewallet   60.25                 4.761905        3.0125     5.5
# 732-04-5373     Cash  185.88                 4.761905        9.2940     7.0
# 794-32-2436  Ewallet  111.34                 4.761905        5.5670     6.0
# 733-33-4967     Cash  166.80                 4.761905        8.3400     6.3
# 642-61-4706     Cash  186.80                 4.761905        9.3400     5.5
#
# [1000 rows x 16 columns]
